# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/matotomoya/Downloads/gdm_materials_discovery/gnome_data/stable_materials_summary.csv")

# %%
df
# Out:
#         Unnamed: 0       Composition  MaterialId Reduced Formula  \
# 0                0          Cs1S6Zr3  000006a8c4       Cs(ZrS2)3
# 1                1      Nd7Os1Pr3Si5  00011f62be     Pr3Nd7Si5Os
# 2                2    Ce2La3Pt16Tm15  00012feb99  La3Ce2Tm15Pt16
# 3                3  Mn1Ni1Os2Sb12Yb1  00014cac13  YbMnNi(Sb6Os)2
# 4                4    Er8Ge4Si12Zr12  0001759321     Er2Zr3Si3Ge
# ...            ...               ...         ...             ...
# 384933      384933      Ga3Lu2Si1Tb4  ffff0b1194     Tb4Lu2Ga3Si
# 384934      384934      Au1Cd3Sm3Sn2  ffff3e9e89     Sm3Cd3Sn2Au
# 384935      384935         Ba1H30Th7  ffff611aad        BaTh7H30
# 384936      384936       Al2Bi8K6Sr6  ffff99b793      K3Sr3AlBi4
# 384937      384937      Au3Cu1Sc8Zn4  fffff156dc     Sc8Zn4CuAu3
#
#                               Elements  NSites    Volume  Density Point Group  \
# 0                    ['S', 'Zr', 'Cs']      10  302.9202   3.2834         2/m
# ...

# %%
df.describe()
# Out:
# /Users/matotomoya/dev/materials_discovery/.venv/lib/python3.12/site-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#           Unnamed: 0         NSites         Volume        Density  \
# count  384938.000000  384938.000000  384938.000000  384938.000000
# mean   192468.500000      21.927443     445.098177       8.308333
# std    111122.173298      10.601832     268.433385       2.730250
# min         0.000000       2.000000      25.842700       0.181500
# 25%     96234.250000      13.000000     245.670500       6.480925
# 50%    192468.500000      21.000000     405.361450       8.349100
# 75%    288702.750000      29.000000     577.577600       9.880400
# max    384937.000000     106.000000    9291.692400      24.096600
#
#        Space Group Number  Corrected Energy  Formation Energy Per Atom  \
# count       384938.000000     384938.000000              384938.000000
# ...

# %%
df = pd.read_csv("/Users/matotomoya/Downloads/gdm_materials_discovery/gnome_data/stable_materials_r2scan.csv")

# %%
df
# Out:
#         Unnamed: 0     Composition  MaterialId Reduced Formula  \
# 0                1    Nd7Os1Pr3Si5  00011f62be     Pr3Nd7Si5Os
# 1                2  Er8Ge4Si12Zr12  0001759321     Er2Zr3Si3Ge
# 2                3    Er2P6Ru12Si1  0001bfac1b    Er2Si(PRu2)6
# 3                4    Al8C4Cu4Zr12  00028a362a       Zr3Al2CuC
# 4                5       I12Li4Np2  00039db7d5         Li2NpI6
# ...            ...             ...         ...             ...
# 139539      163335    Er6Ga1Sb5Zr4  fffebbf080     Er6Zr4GaSb5
# 139540      163336       Ir5Ru5Si6  ffff009f0e      Si6(IrRu)5
# 139541      163337    Ga3Lu2Si1Tb4  ffff0b1194     Tb4Lu2Ga3Si
# 139542      163338    Au1Cd3Sm3Sn2  ffff3e9e89     Sm3Cd3Sn2Au
# 139543      163339     Al2Bi8K6Sr6  ffff99b793      K3Sr3AlBi4
#
#                         Elements  NSites    Volume  Density Point Group  \
# 0       ['Si', 'Pr', 'Nd', 'Os']      16  431.1463   6.7904           1
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0         NSites         Volume        Density  \
# count  139544.000000  139544.000000  139544.000000  139544.000000
# mean    81652.136939      18.840136     367.821978       8.572638
# std     47130.286962       9.092252     215.310844       2.911407
# min         1.000000       3.000000      32.237200       0.502700
# 25%     40816.750000      12.000000     206.240925       6.516500
# 50%     81653.500000      18.000000     308.887500       8.523500
# 75%    122451.250000      24.000000     479.480425      10.251725
# max    163339.000000      84.000000    1709.086700      21.927600
#
#        Space Group Number  Corrected Energy  Formation Energy Per Atom  \
# count       139544.000000     139544.000000              139544.000000
# mean            83.326879       -446.365953                  -0.940014
# std             73.573669        261.042386                   0.702559
# min              1.000000      -2330.314000                  -4.497300
# ...

# %%
df = pd.read_csv("/Users/matotomoya/Downloads/gdm_materials_discovery/gnome_data/stable_materials_hull.csv")

# %%
df
# Out:
#         Unnamed: 0       Composition  Formation Energy Per Atom  \
# 0                0          Cs1S6Zr3                    -1.9058
# 1                1      Nd7Os1Pr3Si5                    -0.5004
# 2                2    Ce2La3Pt16Tm15                    -1.2960
# 3                3  Mn1Ni1Os2Sb12Yb1                    -0.3064
# 4                4    Er8Ge4Si12Zr12                    -0.8718
# ...            ...               ...                        ...
# 384933      384933      Ga3Lu2Si1Tb4                    -0.5925
# 384934      384934      Au1Cd3Sm3Sn2                    -0.6056
# 384935      384935         Ba1H30Th7                    -0.6005
# 384936      384936       Al2Bi8K6Sr6                    -0.6063
# 384937      384937      Au3Cu1Sc8Zn4                    -0.5430
#
#         Corrected Energy
# 0               -70.4155
# 1               -94.0804
# 2              -237.6016
# 3               -93.6931
# 4              -254.0953
# ...                  ...
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0  Formation Energy Per Atom  Corrected Energy
# count  384938.000000              384938.000000     384938.000000
# mean   192468.500000                  -0.917414       -139.376936
# std    111122.173298                   1.213129         81.031625
# min         0.000000                -320.329700      -4256.355500
# 25%     96234.250000                  -0.945300       -183.467800
# 50%    192468.500000                  -0.696000       -124.432950
# 75%    288702.750000                  -0.499900        -79.489550
# max    384937.000000                   0.015800         -5.340800
